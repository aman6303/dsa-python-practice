# %% [markdown]
# ### 1. Case Conversion

# %%
str1 = 'this is DATA SCIENCE'

# %% [markdown]
# #### 1.2 `upper`

# %%
str1.upper()
# Out:
# 'THIS IS DATA SCIENCE'

# %% [markdown]
# #### 1.3 `lower`

# %%
str1.lower()
# Out:
# 'this is data science'

# %% [markdown]
# #### 1.4 `title`

# %%
# capitalize each first word using title

str2 = 'this is data science'

str2.title()
# Out:
# 'This Is Data Science'

# %%
name = 'james anderson'
name.title()
# Out:
# 'James Anderson'

# %% [markdown]
# #### 1.5 `capitalize`

# %%
str2.capitalize() # capitalize first character only
# Out:
# 'This is data science'

# %% [markdown]
# #### 1.6 `swapcase`

# %%
str1
# Out:
# 'this is DATA SCIENCE'

# %%
str1.swapcase()
# Out:
# 'THIS IS data science'

# %% [markdown]
# ### 2. Whitespace Handling

# %%
str1 = '    this is DATA SCIENCE  '
str1
# Out:
# '    this is DATA SCIENCE  '

# %% [markdown]
# #### 1.7 `strip`

# %%
str1.strip()
# Out:
# 'this is DATA SCIENCE'

# %% [markdown]
# #### 1.8 `lstrip`

# %%
str1.lstrip()  # only left strip
# Out:
# 'this is DATA SCIENCE  '

# %% [markdown]
# #### 1.9 `rstrip`

# %%
str1.rstrip()  # doing right strip only
# Out:
# '    this is DATA SCIENCE'

# %%
str2 = '###$$$this is DATA SCIENCE###$$$'

# %%
str2.lstrip('#').lstrip('$')   # stripping other character
# Out:
# 'this is DATA SCIENCE###$$$'

# %% [markdown]
# ### 3. Searching & Finding

# %%
str1 = 'this is data science and data engineering'
str1
# Out:
# 'this is data science and data engineering'

# %% [markdown]
# #### `find`

# %%
str1.find('data')
# Out:
# 8

# %%
str1[8]
# Out:
# 'd'

# %%
str1.find('ML')
# Out:
# -1

# %% [markdown]
# #### `index`

# %%
str1.index('data')
# Out:
# 8

# %%
str1.index('ML')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 str1.index('ML')
#
# ValueError: substring not found

# %% [markdown]
# #### `startswith`

# %%
str1
# Out:
# 'this is data science and data engineering'

# %%
str1.startswith('this')
# Out:
# True

# %%
str1.startswith('tha')
# Out:
# False

# %% [markdown]
# #### `endswith`

# %%
str1.endswith('ng')
# Out:
# True

# %%
str1.endswith('ag')
# Out:
# False

# %% [markdown]
# ### 4. Validation Checks

# %%
str1
# Out:
# '    this is DATA SCIENCE  '

# %%
str2 = '1234'

# %% [markdown]
# #### `isdigit`

# %%
str2.isdigit()
# Out:
# True

# %%
'123 abc'.isdigit()
# Out:
# False

# %% [markdown]
# #### `isalpha`

# %%
'abcdABCD'.isalpha()
# Out:
# True

# %% [markdown]
# #### `isalnum`

# %%
'abc123'.isalnum()
# Out:
# True

# %% [markdown]
# #### `islower`

# %%
'abcd'.islower()
# Out:
# True

# %% [markdown]
# #### `isupper`

# %%
'ABC'.isupper()
# Out:
# True

# %% [markdown]
# #### `isspace`

# %%
'       '.isspace()  # if all are spaces
# Out:
# True

# %% [markdown]
# ### 5. Splitting & Joining

# %%
str1
# Out:
# '    this is DATA SCIENCE  '

# %% [markdown]
# #### `split`

# %%
str1.split()
# Out:
# ['this', 'is', 'DATA', 'SCIENCE']

# %% [markdown]
# #### `join`

# %%
res = str1.split()
res
# Out:
# ['this', 'is', 'DATA', 'SCIENCE']

# %%
' '.join(res).title()
# Out:
# 'This Is Data Science'

# %% [markdown]
# ### 6. Replacement

# %% [markdown]
# #### `replace`

# %%
str1
# Out:
# '    this is DATA SCIENCE  '

# %%
str1.replace('science', 'analysis')
# Out:
# '    this is DATA SCIENCE  '

# %% [markdown]
# ### 7. Counting & Measuring

# %%
str1
# Out:
# '    this is DATA SCIENCE  '

# %% [markdown]
# #### `len`

# %%
len(str1)
# Out:
# 26

# %% [markdown]
# #### `count`

# %%
str1.count('data')
# Out:
# 0

# %%
str1.count('ML')
# Out:
# 0

# %% [markdown]
# ### 8. String Formatting

# %% [markdown]
# #### `f-strings`

# %%
first = 'James'
last = 'Anderson'
age = 25

res = f'My name is {first} {last} and I am {age} years old.'
print(res)
# Out:
# My name is James Anderson and I am 25 years old.

# %%
acc = 0.98
print(f'Model accuracy: {acc}')
# Out:
# Model accuracy: 0.98
